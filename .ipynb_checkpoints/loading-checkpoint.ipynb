# %%
import pandas as pd

df = pd.read_csv("leetcode-problem-dataset/leetcode_dataset.csv")

# print(df.iloc[0])      # first row
# print(df.head())       # first 5 rows
# print(len(df))         # number of rows
print(df.columns)      # column names
# Out:
# Index(['id', 'title', 'description', 'is_premium', 'difficulty',
#        'solution_link', 'acceptance_rate', 'frequency', 'url', 'discuss_count',
#        'accepted', 'submissions', 'companies', 'related_topics', 'likes',
#        'dislikes', 'rating', 'asked_by_faang', 'similar_questions'],
#       dtype='str')

# %%
import pandas as pd

df = pd.read_csv("codeforces-competitive-programming-dataset/raw_dataset.csv")

print(df.columns)      # column names
# Out:
# Index(['problem_link', 'problem_id', 'problem_idx', 'short_id',
#        'contest_number', 'problem_name', 'problem_statement',
#        'problem_solution', 'problem_input', 'problem_output', 'problem_tags',
#        'problem_dificulty', 'file_name', 'editorial_link',
#        'problem_editorial'],
#       dtype='str')

# %%
import pandas as pd

df_q = pd.read_csv("codechef-competitive-programming/questions.csv")
df_s = pd.read_csv("codechef-competitive-programming/solutions.csv")

print(df_q.columns)      # column names
print(df_s.columns)      # column names
# Out:
# Index(['QCode', 'Title', 'link', 'level', 'statement', 'Author', 'Tester',
#        'Editorial', 'Tags', 'Date Added', 'Time Limit', 'Source Limit',
#        'Languages'],
#       dtype='str')
# Index(['QCode', 'SolutionID', 'timeago', 'UserID', 'Status', 'TimeTaken',
#        'MemTaken', 'Language', 'SolutionUrl'],
#       dtype='str')
