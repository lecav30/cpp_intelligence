# %%
import pandas as pd

merged = pd.read_csv("competitive_programming_dataset.csv")

# merged.info()
# merged.head()
merged.isna().sum()
# merged.duplicated().sum()
# merged.dtypes
# merged.nunique()
# Out:
# platform                    0
# source_id                   0
# title                       0
# url                         0
# statement                   0
# difficulty_raw              0
# difficulty_normalized       0
# tags_raw                  254
# editorial_url            1086
# dtype: int64
